# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Q1.9
# Order the fuzzy sets defined by the following membership grade functions (assuming $x \geq 0$) by the inclusion (subset) relation:
#
# $$
# \mu_A(x) = \frac{1}{1 + 10x};\qquad \mu_B(x) = \left(\frac{1}{1+10x}\right)^{1/2};\qquad \mu_C(x) = \left(\frac{1}{1+10x}\right)^{2}
# $$
#
# **Answer**:
# > Let $P$ and $Q$ be fuzzy-sets defined on the same universal set $X$. Then, $P\subseteq Q$ iff $\mu_P(x) \leq \mu_Q(X)\,\, \forall x \in X$.
# >
# > The following plot shows that $C \subseteq A \subseteq B$.

# %%
_, axs = plt.subplots(nrows=1, ncols=1, figsize=(15,10))

x = np.arange(start=0, step=0.001, stop=5)
u_A = 1 / (1 + 10 * x)
u_B = np.sqrt(u_A)
u_C = np.square(u_A)

axs.plot(x, u_A, label=r"$\mu_A(x)$")
axs.plot(x, u_B, label=r"$\mu_B(x)$")
axs.plot(x, u_C, label=r"$\mu_C(x)$")

axs.set_xlabel(r"$X\rightarrow$")
axs.set_ylabel(r"$\mu_{A,B,C}(x)\rightarrow$")
axs.set_title("Plot of membership functions")
axs.legend()

plt.show()

# %% [markdown]
# # Q1.10
# Consider the fuzzy sts $A$, $B$, and $C$ defined on the interval $X = [0, 1]$ of real numbers by the membership grade functions
#
# $$
# \mu_A(x) = \frac{x}{x + 2};\qquad \mu_B(x) = 2^{-x};\qquad \mu_C(x) = \frac{1}{1+10(x-2)^{2}}
# $$
#
# Determine mathematical formulas and graphs of the membership grade functions of each of the following sets:
# 1. $\bar{A};\,\, \bar{B};\,\, \bar{C}$
# 2. $A\cup B;\,\, A\cup C;\,\, B\cup C$
# 3. $A\cap B;\,\, A\cap C;\,\, B\cap C$
# 4. $A\cup B\cup C;\,\, A\cap B\cap C$
# 5. $A\cap \bar{C};\,\, \bar{B\cap C};\,\, \bar{A\cup C}$

# %%
# part-1
_, axs = plt.subplots(nrows=1, ncols=1, figsize=(15,10))

x = np.arange(start=0, stop=1, step=0.01)
u_A = x / (x + 2)
u_B = np.power(2, -1 * x)
u_C = 1 / (1 + 10 * np.square(x - 2))

axs.plot(x, u_A, label=r"$\mu_A(x)$")
axs.plot(x, u_B, label=r"$\mu_B(x)$")
axs.plot(x, u_C, label=r"$\mu_C(x)$")

axs.set_xlabel(r"$X\rightarrow$")
axs.set_ylabel(r"$\mu_{A,B,C}(x)\rightarrow$")
axs.set_title("Plots of membership functions")
axs.legend()

plt.show()
